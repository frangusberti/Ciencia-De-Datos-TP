# %% [markdown]
# # Exploración del Dataset Limpio
# Este archivo te permite visualizar el dataset `customer_behavior_LIMPIO.csv` en formato tabla y es el punto de partida ideal para tu fase de modelo predictivo.

# %%
import pandas as pd

# Permitir que Pandas muestre todas las columnas
pd.set_option('display.max_columns', None)

# Cargar el dataset limpio
df = pd.read_csv('customer_behavior_LIMPIO.csv')

# Visualizar las primeras 20 filas en formato tabla interactiva
df.head(20)

# %%
# Ver información de las columnas y tipos de datos
df.info()
